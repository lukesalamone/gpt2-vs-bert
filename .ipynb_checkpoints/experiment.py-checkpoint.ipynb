# %%
import torch
from torch import topk
from transformers import BertTokenizer, BertForMaskedLM
from datasets import load_dataset
import numpy as np
from numpy.random import randint
from torch.nn.functional import softmax

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForMaskedLM.from_pretrained('bert-base-uncased')
inputs = tokenizer("The capital of France is [MASK].", return_tensors="pt")
labels = tokenizer("The capital of France is Paris.", return_tensors="pt")["input_ids"]
outputs = model(**inputs, labels=labels)
loss = outputs.loss
logits = outputs.logits
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
wikitext2 = load_dataset('wikitext', 'wikitext-2-v1')
# Out:
# Reusing dataset wikitext (/Users/luke/.cache/huggingface/datasets/wikitext/wikitext-2-v1/1.0.0/aa5e094000ec7afeb74c3be92c88313cd6f132d564c7effd961c10fd47c76f20)

# %%
cleaned = [x['text'].strip() for x in wikitext2['test']]
cleaned = [x for x in cleaned if(len(x) > 50)]

# %%
wiki_clean = [x for x in cleaned if len(tokenizer(x)['input_ids']) <= 512]

# %%
def get_random_sequences(data, num=10_000, max_seq_len=512):
    response = []
    
    # get num sentences corresponding to random indices and tokenize them
    lines = [data[i] for i in randint(len(data), size=num)]
    
    response = []
    
    while len(response) < num:
        line = data[randint(len(data))]
        text = line.split(' ')
        idx = randint(len(text))
        text[idx] = '[MASK]'
        masked = ' '.join(text)
        
        if len(tokenizer(masked)['input_ids']) > max_seq_len:
            continue
            
        response.append((line, masked))
    
    return response

# %%
def get_random_sequence_fixed():

# %%
def masked_prediction(text, masked, model):
    tokenized_text = tokenizer.tokenize(text)
    tokenized_masked = tokenizer.tokenize(masked)
    token_ids = tokenizer.convert_tokens_to_ids(tokenized_masked)
    mask_idx = token_ids.index(103)
    actual = tokenized_text[mask_idx]
    
    with torch.no_grad():
        predictions = model(torch.tensor([token_ids]))[0]

    probs = softmax(predictions[0, mask_idx], dim=-1)
    top_k_weights, top_k_indices = torch.topk(probs, 1)
    
    for i, pred_idx in enumerate(top_k_indices):
        predicted_token = tokenizer.convert_ids_to_tokens([pred_idx])[0]
        token_weight = top_k_weights[i]
        
    return {'predicted': predicted_token, 'actual': actual, 'mask_idx': mask_idx, 'num_tokens': len(token_ids)}

# %%
sequences = get_random_sequences(cleaned)

# %%
performance = []
for i,seq in enumerate(sequences):
    x = masked_prediction(seq[0], seq[1], model)
    print(f'{i+1}/{len(sequences)} ({int((i+1)*100/len(sequences))}%)\t {x}')
    performance.append(x)
# Out:
# 1/10000 (0%)	 {'predicted': 'next', 'actual': 'following', 'mask_idx': 169}
# 2/10000 (0%)	 {'predicted': 'armor', 'actual': 'armor', 'mask_idx': 58}
# 3/10000 (0%)	 {'predicted': 'refers', 'actual': 'refers', 'mask_idx': 58}
# 4/10000 (0%)	 {'predicted': 'designs', 'actual': 'works', 'mask_idx': 53}
# 5/10000 (0%)	 {'predicted': 'those', 'actual': 'those', 'mask_idx': 110}
# 6/10000 (0%)	 {'predicted': '2', 'actual': '46', 'mask_idx': 150}
# 7/10000 (0%)	 {'predicted': 'which', 'actual': 'which', 'mask_idx': 27}
# 8/10000 (0%)	 {'predicted': 'game', 'actual': 'game', 'mask_idx': 77}
# 9/10000 (0%)	 {'predicted': 'is', 'actual': ',', 'mask_idx': 1}
# 10/10000 (0%)	 {'predicted': '2', 'actual': '3', 'mask_idx': 48}
# 11/10000 (0%)	 {'predicted': 'and', 'actual': 'and', 'mask_idx': 54}
# 12/10000 (0%)	 {'predicted': 'furthermore', 'actual': 'long', 'mask_idx': 1}
# 13/10000 (0%)	 {'predicted': 'steel', 'actual': 'wood', 'mask_idx': 6}
# 14/10000 (0%)	 {'predicted': '.', 'actual': 'from', 'mask_idx': 15}
# 15/10000 (0%)	 {'predicted': 'had', 'actual': 'had', 'mask_idx': 46}
# 16/10000 (0%)	 {'predicted': 'other', 'actual': 'government', 'mask_idx': 21}
# 17/10000 (0%)	 {'predicted': 'underwent', 'actual': 'underwent', 'mask_idx': 89}
# 18/10000 (0%)	 {'predicted': 'for', 'actual': 'for', 'mask_idx': 64}
# 19/10000 (0%)	 {'predicted': 'of', 'actual': 'of', 'mask_idx': 42}
# 20/10000 (0%)	 {'predicted': 'it', 'actual': 'it', 'mask_idx': 168}
# 21/10000 (0%)	 {'predicted': 'on', 'actual': 'on', 'mask_idx': 119}
# 22/10000 (0%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 146}
# 23/10000 (0%)	 {'predicted': '.', 'actual': '<', 'mask_idx': 23}
# 24/10000 (0%)	 {'predicted': 'is', 'actual': 'is', 'mask_idx': 86}
# 25/10000 (0%)	 {'predicted': 'fire', 'actual': 'fire', 'mask_idx': 42}
# 26/10000 (0%)	 {'predicted': 'coach', 'actual': 'president', 'mask_idx': 43}
# 27/10000 (0%)	 {'predicted': 'a', 'actual': 'a', 'mask_idx': 22}
# 28/10000 (0%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 48}
# 29/10000 (0%)	 {'predicted': 'a', 'actual': 'a', 'mask_idx': 202}
# 30/10000 (0%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 82}
# 31/10000 (0%)	 {'predicted': 'by', 'actual': 'by', 'mask_idx': 12}
# 32/10000 (0%)	 {'predicted': '80', 'actual': '14', 'mask_idx': 107}
# 33/10000 (0%)	 {'predicted': 'coach', 'actual': 'coach', 'mask_idx': 90}
# 34/10000 (0%)	 {'predicted': 'to', 'actual': "'", 'mask_idx': 38}
# 35/10000 (0%)	 {'predicted': 'ships', 'actual': 'airs', 'mask_idx': 67}
# 36/10000 (0%)	 {'predicted': 'his', 'actual': 'his', 'mask_idx': 5}
# 37/10000 (0%)	 {'predicted': 'not', 'actual': 'had', 'mask_idx': 16}
# 38/10000 (0%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 47}
# 39/10000 (0%)	 {'predicted': 'above', 'actual': 'method', 'mask_idx': 16}
# 40/10000 (0%)	 {'predicted': 'darwin', 'actual': '<', 'mask_idx': 52}
# 41/10000 (0%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 145}
# 42/10000 (0%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 47}
# 43/10000 (0%)	 {'predicted': 'were', 'actual': 'were', 'mask_idx': 157}
# 44/10000 (0%)	 {'predicted': 'the', 'actual': 'deep', 'mask_idx': 284}
# 45/10000 (0%)	 {'predicted': 'battle', 'actual': 'morning', 'mask_idx': 76}
# 46/10000 (0%)	 {'predicted': 'engaged', 'actual': 'involved', 'mask_idx': 40}
# 47/10000 (0%)	 {'predicted': 'h', 'actual': 'h', 'mask_idx': 251}
# 48/10000 (0%)	 {'predicted': 'was', 'actual': 'was', 'mask_idx': 31}
# 49/10000 (0%)	 {'predicted': '113', 'actual': '99', 'mask_idx': 66}
# 50/10000 (0%)	 {'predicted': '$', 'actual': '$', 'mask_idx': 115}
# 51/10000 (0%)	 {'predicted': 'variety', 'actual': 'mix', 'mask_idx': 153}
# 52/10000 (0%)	 {'predicted': 'defensive', 'actual': 'at', 'mask_idx': 69}
# 53/10000 (0%)	 {'predicted': 'can', 'actual': 'can', 'mask_idx': 239}
# 54/10000 (0%)	 {'predicted': 'monument', 'actual': 'monument', 'mask_idx': 8}
# 55/10000 (0%)	 {'predicted': 'us', 'actual': 'us', 'mask_idx': 22}
# 56/10000 (0%)	 {'predicted': 'base', 'actual': 'base', 'mask_idx': 46}
# 57/10000 (0%)	 {'predicted': 'as', 'actual': 'to', 'mask_idx': 45}
# 58/10000 (0%)	 {'predicted': '##d', 'actual': '@', 'mask_idx': 15}
# 59/10000 (0%)	 {'predicted': 'latin', 'actual': '<', 'mask_idx': 158}
# 60/10000 (0%)	 {'predicted': 'days', 'actual': 'days', 'mask_idx': 162}
# 61/10000 (0%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 38}
# 62/10000 (0%)	 {'predicted': 'days', 'actual': 'hours', 'mask_idx': 100}
# 63/10000 (0%)	 {'predicted': '[', 'actual': 'noted', 'mask_idx': 14}
# 64/10000 (0%)	 {'predicted': '=', 'actual': '=', 'mask_idx': 18}
# 65/10000 (0%)	 {'predicted': 'in', 'actual': 'in', 'mask_idx': 51}
# 66/10000 (0%)	 {'predicted': 'usa', 'actual': 'california', 'mask_idx': 25}
# 67/10000 (0%)	 {'predicted': 'and', 'actual': '.', 'mask_idx': 140}
# 68/10000 (0%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 10}
# 69/10000 (0%)	 {'predicted': 'class', 'actual': '10', 'mask_idx': 114}
# 70/10000 (0%)	 {'predicted': 'while', 'actual': 'and', 'mask_idx': 107}
# 71/10000 (0%)	 {'predicted': 'british', 'actual': 'commonwealth', 'mask_idx': 112}
# 72/10000 (0%)	 {'predicted': 'the', 'actual': 'increasing', 'mask_idx': 8}
# 73/10000 (0%)	 {'predicted': ',', 'actual': 'center', 'mask_idx': 4}
# 74/10000 (0%)	 {'predicted': ':', 'actual': '(', 'mask_idx': 2}
# 75/10000 (0%)	 {'predicted': 'gets', 'actual': '<', 'mask_idx': 376}
# 76/10000 (0%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 219}
# 77/10000 (0%)	 {'predicted': 'and', 'actual': 'and', 'mask_idx': 80}
# 78/10000 (0%)	 {'predicted': 'world', 'actual': 'world', 'mask_idx': 19}
# 79/10000 (0%)	 {'predicted': 'was', 'actual': 'was', 'mask_idx': 157}
# 80/10000 (0%)	 {'predicted': 'singapore', 'actual': '<', 'mask_idx': 7}
# 81/10000 (0%)	 {'predicted': ',', 'actual': '—', 'mask_idx': 229}
# 82/10000 (0%)	 {'predicted': 'a', 'actual': 'a', 'mask_idx': 49}
# 83/10000 (0%)	 {'predicted': 'end', 'actual': 'jumps', 'mask_idx': 17}
# 84/10000 (0%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 268}
# 85/10000 (0%)	 {'predicted': 'originally', 'actual': 'initially', 'mask_idx': 167}
# 86/10000 (0%)	 {'predicted': 'designs', 'actual': 'instruments', 'mask_idx': 136}
# 87/10000 (0%)	 {'predicted': 'based', 'actual': 'based', 'mask_idx': 78}
# 88/10000 (0%)	 {'predicted': 'use', 'actual': 'influence', 'mask_idx': 6}
# 89/10000 (0%)	 {'predicted': '1856', 'actual': '1858', 'mask_idx': 58}
# 90/10000 (0%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 61}
# 91/10000 (0%)	 {'predicted': 'of', 'actual': 'towards', 'mask_idx': 176}
# 92/10000 (0%)	 {'predicted': 'articles', 'actual': '<', 'mask_idx': 209}
# 93/10000 (0%)	 {'predicted': 'it', 'actual': 'it', 'mask_idx': 96}
# 94/10000 (0%)	 {'predicted': '(', 'actual': '(', 'mask_idx': 7}
# 95/10000 (0%)	 {'predicted': 'first', 'actual': 'dream', 'mask_idx': 90}
# 96/10000 (0%)	 {'predicted': 'of', 'actual': 'of', 'mask_idx': 74}
# 97/10000 (0%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 82}
# 98/10000 (0%)	 {'predicted': 'important', 'actual': 'serious', 'mask_idx': 74}
# 99/10000 (0%)	 {'predicted': 'has', 'actual': 'has', 'mask_idx': 4}
# 100/10000 (1%)	 {'predicted': '2011', 'actual': '2012', 'mask_idx': 22}
# 101/10000 (1%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 175}
# 102/10000 (1%)	 {'predicted': 'because', 'actual': 'because', 'mask_idx': 258}
# 103/10000 (1%)	 {'predicted': '1941', 'actual': '1942', 'mask_idx': 75}
# 104/10000 (1%)	 {'predicted': 'of', 'actual': 'of', 'mask_idx': 147}
# 105/10000 (1%)	 {'predicted': 'been', 'actual': 'been', 'mask_idx': 33}
# 106/10000 (1%)	 {'predicted': '-', 'actual': '@', 'mask_idx': 40}
# 107/10000 (1%)	 {'predicted': 'single', 'actual': 'senior', 'mask_idx': 324}
# 108/10000 (1%)	 {'predicted': '.', 'actual': '<', 'mask_idx': 156}
# 109/10000 (1%)	 {'predicted': '"', 'actual': '=', 'mask_idx': 0}
# 110/10000 (1%)	 {'predicted': 'uses', 'actual': 'uses', 'mask_idx': 55}
# 111/10000 (1%)	 {'predicted': 'line', 'actual': 'road', 'mask_idx': 139}
# 112/10000 (1%)	 {'predicted': 'he', 'actual': 'he', 'mask_idx': 189}
# 113/10000 (1%)	 {'predicted': 'time', 'actual': 'time', 'mask_idx': 60}
# 114/10000 (1%)	 {'predicted': 'in', 'actual': 'of', 'mask_idx': 85}
# 115/10000 (1%)	 {'predicted': '+', 'actual': '3', 'mask_idx': 62}
# 116/10000 (1%)	 {'predicted': 'for', 'actual': 'for', 'mask_idx': 65}
# 117/10000 (1%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 180}
# 118/10000 (1%)	 {'predicted': 'the', 'actual': 'ars', 'mask_idx': 185}
# 119/10000 (1%)	 {'predicted': 'by', 'actual': 'by', 'mask_idx': 28}
# 120/10000 (1%)	 {'predicted': ',', 'actual': '<', 'mask_idx': 13}
# 121/10000 (1%)	 {'predicted': 'large', 'actual': 'broad', 'mask_idx': 7}
# 122/10000 (1%)	 {'predicted': 'heard', 'actual': 'learned', 'mask_idx': 151}
# 123/10000 (1%)	 {'predicted': '1', 'actual': '1', 'mask_idx': 47}
# 124/10000 (1%)	 {'predicted': 'hire', 'actual': 'hire', 'mask_idx': 193}
# 125/10000 (1%)	 {'predicted': 'at', 'actual': 'at', 'mask_idx': 154}
# 126/10000 (1%)	 {'predicted': 'use', 'actual': 'favour', 'mask_idx': 6}
# 127/10000 (1%)	 {'predicted': 'way', 'actual': 'way', 'mask_idx': 138}
# 128/10000 (1%)	 {'predicted': '-', 'actual': '<', 'mask_idx': 53}
# 129/10000 (1%)	 {'predicted': 'as', 'actual': 'as', 'mask_idx': 32}
# 130/10000 (1%)	 {'predicted': 'submarines', 'actual': '<', 'mask_idx': 144}
# 131/10000 (1%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 80}
# 132/10000 (1%)	 {'predicted': 'walker', 'actual': 'walker', 'mask_idx': 6}
# 133/10000 (1%)	 {'predicted': 'in', 'actual': 'of', 'mask_idx': 3}
# 134/10000 (1%)	 {'predicted': '?', 'actual': '1824', 'mask_idx': 185}
# 135/10000 (1%)	 {'predicted': 'south', 'actual': 'south', 'mask_idx': 293}
# 136/10000 (1%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 30}
# 137/10000 (1%)	 {'predicted': 'attention', 'actual': 'attention', 'mask_idx': 235}
# 138/10000 (1%)	 {'predicted': '=', 'actual': '=', 'mask_idx': 2}
# 139/10000 (1%)	 {'predicted': '"', 'actual': '"', 'mask_idx': 67}
# 140/10000 (1%)	 {'predicted': 'to', 'actual': ',', 'mask_idx': 93}
# 141/10000 (1%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 319}
# 142/10000 (1%)	 {'predicted': 'would', 'actual': 'would', 'mask_idx': 129}
# 143/10000 (1%)	 {'predicted': 'he', 'actual': 'mccarthy', 'mask_idx': 37}
# 144/10000 (1%)	 {'predicted': 'standing', 'actual': 'ground', 'mask_idx': 50}
# 145/10000 (1%)	 {'predicted': 'people', 'actual': 'recruitment', 'mask_idx': 73}
# 146/10000 (1%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 58}
# 147/10000 (1%)	 {'predicted': 'moved', 'actual': 'advanced', 'mask_idx': 69}
# 148/10000 (1%)	 {'predicted': 'officers', 'actual': 'officers', 'mask_idx': 73}
# 149/10000 (1%)	 {'predicted': 'face', 'actual': 'head', 'mask_idx': 46}
# 150/10000 (1%)	 {'predicted': 'complete', 'actual': 'substantial', 'mask_idx': 26}
# 151/10000 (1%)	 {'predicted': 'football', 'actual': 'football', 'mask_idx': 22}
# 152/10000 (1%)	 {'predicted': 'elects', 'actual': 'elects', 'mask_idx': 56}
# 153/10000 (1%)	 {'predicted': 'were', 'actual': 'are', 'mask_idx': 53}
# 154/10000 (1%)	 {'predicted': 'personal', 'actual': 'provincial', 'mask_idx': 127}
# 155/10000 (1%)	 {'predicted': 'dissipated', 'actual': 'passed', 'mask_idx': 28}
# 156/10000 (1%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 7}
# 157/10000 (1%)	 {'predicted': ',', 'actual': '–', 'mask_idx': 21}
# 158/10000 (1%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 54}
# 159/10000 (1%)	 {'predicted': ',', 'actual': 'soldiers', 'mask_idx': 17}
# 160/10000 (1%)	 {'predicted': 'was', 'actual': 'felt', 'mask_idx': 63}
# 161/10000 (1%)	 {'predicted': '.', 'actual': 'bearing', 'mask_idx': 14}
# 162/10000 (1%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 9}
# 163/10000 (1%)	 {'predicted': 'at', 'actual': 'at', 'mask_idx': 47}
# 164/10000 (1%)	 {'predicted': '<', 'actual': '.', 'mask_idx': 96}
# 165/10000 (1%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 173}
# 166/10000 (1%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 23}
# 167/10000 (1%)	 {'predicted': ':', 'actual': '–', 'mask_idx': 34}
# 168/10000 (1%)	 {'predicted': 'likeness', 'actual': 'gardens', 'mask_idx': 166}
# 169/10000 (1%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 74}
# 170/10000 (1%)	 {'predicted': 'and', 'actual': 'and', 'mask_idx': 14}
# 171/10000 (1%)	 {'predicted': 'and', 'actual': 'and', 'mask_idx': 270}
# 172/10000 (1%)	 {'predicted': '.', 'actual': 'by', 'mask_idx': 20}
# 173/10000 (1%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 46}
# 174/10000 (1%)	 {'predicted': 'bombers', 'actual': 'bombers', 'mask_idx': 112}
# 175/10000 (1%)	 {'predicted': 'music', 'actual': 'prominently', 'mask_idx': 162}
# 176/10000 (1%)	 {'predicted': ',', 'actual': 'is', 'mask_idx': 112}
# 177/10000 (1%)	 {'predicted': 'it', 'actual': '<', 'mask_idx': 56}
# 178/10000 (1%)	 {'predicted': 'create', 'actual': 'build', 'mask_idx': 36}
# 179/10000 (1%)	 {'predicted': 'each', 'actual': 'four', 'mask_idx': 47}
# 180/10000 (1%)	 {'predicted': ')', 'actual': 'workers', 'mask_idx': 77}
# 181/10000 (1%)	 {'predicted': '4', 'actual': '0', 'mask_idx': 129}
# 182/10000 (1%)	 {'predicted': 'earnings', 'actual': '<', 'mask_idx': 46}
# 183/10000 (1%)	 {'predicted': 'the', 'actual': 'existing', 'mask_idx': 103}
# 184/10000 (1%)	 {'predicted': '##ain', 'actual': '<', 'mask_idx': 17}
# 185/10000 (1%)	 {'predicted': ')', 'actual': ')', 'mask_idx': 61}
# 186/10000 (1%)	 {'predicted': 'stand', 'actual': 'stand', 'mask_idx': 252}
# 187/10000 (1%)	 {'predicted': 'the', 'actual': 'two', 'mask_idx': 119}
# 188/10000 (1%)	 {'predicted': 'them', 'actual': 'iron', 'mask_idx': 18}
# 189/10000 (1%)	 {'predicted': 'with', 'actual': 'with', 'mask_idx': 24}
# 190/10000 (1%)	 {'predicted': 'public', 'actual': 'military', 'mask_idx': 2}
# 191/10000 (1%)	 {'predicted': 'they', 'actual': 'they', 'mask_idx': 88}
# 192/10000 (1%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 96}
# 193/10000 (1%)	 {'predicted': '30', 'actual': '15', 'mask_idx': 2}
# 194/10000 (1%)	 {'predicted': 'rest', 'actual': 'rest', 'mask_idx': 209}
# 195/10000 (1%)	 {'predicted': 'more', 'actual': 'more', 'mask_idx': 157}
# 196/10000 (1%)	 {'predicted': '-', 'actual': ',', 'mask_idx': 2}
# 197/10000 (1%)	 {'predicted': 'and', 'actual': 'and', 'mask_idx': 46}
# 198/10000 (1%)	 {'predicted': 'more', 'actual': 'less', 'mask_idx': 6}
# 199/10000 (1%)	 {'predicted': 'yeshiva', 'actual': 'syracuse', 'mask_idx': 75}
# 200/10000 (2%)	 {'predicted': 'to', 'actual': 'to', 'mask_idx': 20}
# 201/10000 (2%)	 {'predicted': 'of', 'actual': 'of', 'mask_idx': 26}
# 202/10000 (2%)	 {'predicted': 'live', 'actual': 'concert', 'mask_idx': 34}
# 203/10000 (2%)	 {'predicted': 'games', 'actual': 'games', 'mask_idx': 82}
# 204/10000 (2%)	 {'predicted': 'others', 'actual': 'mercury', 'mask_idx': 93}
# 205/10000 (2%)	 {'predicted': 'state', 'actual': 'military', 'mask_idx': 74}
# 206/10000 (2%)	 {'predicted': 'was', 'actual': 'featured', 'mask_idx': 57}
# 207/10000 (2%)	 {'predicted': 'the', 'actual': '<', 'mask_idx': 7}
# 208/10000 (2%)	 {'predicted': 'industrial', 'actual': 'trade', 'mask_idx': 117}
# 209/10000 (2%)	 {'predicted': '10', 'actual': '10', 'mask_idx': 26}
# 210/10000 (2%)	 {'predicted': 'for', 'actual': 'underneath', 'mask_idx': 121}
# 211/10000 (2%)	 {'predicted': 'to', 'actual': 'to', 'mask_idx': 122}
# 212/10000 (2%)	 {'predicted': 'son', 'actual': 'son', 'mask_idx': 15}
# 213/10000 (2%)	 {'predicted': 'would', 'actual': 'would', 'mask_idx': 34}
# 214/10000 (2%)	 {'predicted': 'logic', 'actual': 'command', 'mask_idx': 48}
# 215/10000 (2%)	 {'predicted': '##s', 'actual': 'public', 'mask_idx': 28}
# 216/10000 (2%)	 {'predicted': 'stating', 'actual': 'warning', 'mask_idx': 78}
# 217/10000 (2%)	 {'predicted': 'band', 'actual': 'band', 'mask_idx': 66}
# 218/10000 (2%)	 {'predicted': '14', 'actual': '19', 'mask_idx': 50}
# 219/10000 (2%)	 {'predicted': ':', 'actual': 'induced', 'mask_idx': 23}
# 220/10000 (2%)	 {'predicted': 'to', 'actual': 'to', 'mask_idx': 67}
# 221/10000 (2%)	 {'predicted': 'as', 'actual': 'as', 'mask_idx': 140}
# 222/10000 (2%)	 {'predicted': 'colonial', 'actual': 'neoclassical', 'mask_idx': 15}
# 223/10000 (2%)	 {'predicted': 'once', 'actual': 'after', 'mask_idx': 30}
# 224/10000 (2%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 66}
# 225/10000 (2%)	 {'predicted': 'fast', 'actual': 'slow', 'mask_idx': 18}
# 226/10000 (2%)	 {'predicted': 'living', 'actual': 'a', 'mask_idx': 160}
# 227/10000 (2%)	 {'predicted': 'from', 'actual': 'from', 'mask_idx': 101}
# 228/10000 (2%)	 {'predicted': 'composition', 'actual': 'australia', 'mask_idx': 147}
# 229/10000 (2%)	 {'predicted': 'values', 'actual': 'organisation', 'mask_idx': 66}
# 230/10000 (2%)	 {'predicted': 'combined', 'actual': 'artillery', 'mask_idx': 134}
# 231/10000 (2%)	 {'predicted': 'in', 'actual': 'in', 'mask_idx': 65}
# 232/10000 (2%)	 {'predicted': 'tons', 'actual': 't', 'mask_idx': 68}
# 233/10000 (2%)	 {'predicted': 'creek', 'actual': 'creek', 'mask_idx': 161}
# 234/10000 (2%)	 {'predicted': 'organization', 'actual': 'organization', 'mask_idx': 53}
# 235/10000 (2%)	 {'predicted': 'great', 'actual': 'remarkable', 'mask_idx': 125}
# 236/10000 (2%)	 {'predicted': 'loan', 'actual': 'loan', 'mask_idx': 18}
# 237/10000 (2%)	 {'predicted': 'may', 'actual': 'february', 'mask_idx': 138}
# 238/10000 (2%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 13}
# 239/10000 (2%)	 {'predicted': 'most', 'actual': 'several', 'mask_idx': 40}
# 240/10000 (2%)	 {'predicted': 'his', 'actual': "'", 'mask_idx': 168}
# 241/10000 (2%)	 {'predicted': 'also', 'actual': 'also', 'mask_idx': 38}
# 242/10000 (2%)	 {'predicted': '.', 'actual': '@', 'mask_idx': 106}
# 243/10000 (2%)	 {'predicted': 'would', 'actual': 'would', 'mask_idx': 92}
# 244/10000 (2%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 32}
# 245/10000 (2%)	 {'predicted': 'the', 'actual': 'cities', 'mask_idx': 1}
# 246/10000 (2%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 110}
# 247/10000 (2%)	 {'predicted': 'of', 'actual': 'of', 'mask_idx': 36}
# 248/10000 (2%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 134}
# 249/10000 (2%)	 {'predicted': 'may', 'actual': 'march', 'mask_idx': 14}
# 250/10000 (2%)	 {'predicted': 'no', 'actual': '<', 'mask_idx': 54}
# 251/10000 (2%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 73}
# 252/10000 (2%)	 {'predicted': 'the', 'actual': 'current', 'mask_idx': 1}
# 253/10000 (2%)	 {'predicted': 'use', 'actual': 'use', 'mask_idx': 288}
# 254/10000 (2%)	 {'predicted': 'war', 'actual': 'war', 'mask_idx': 10}
# 255/10000 (2%)	 {'predicted': '8', 'actual': '1', 'mask_idx': 12}
# 256/10000 (2%)	 {'predicted': 'front', 'actual': 'ridge', 'mask_idx': 90}
# 257/10000 (2%)	 {'predicted': 'ceded', 'actual': 'ceded', 'mask_idx': 10}
# 258/10000 (2%)	 {'predicted': 'as', 'actual': 'for', 'mask_idx': 14}
# 259/10000 (2%)	 {'predicted': 'was', 'actual': 'began', 'mask_idx': 136}
# 260/10000 (2%)	 {'predicted': '(', 'actual': '(', 'mask_idx': 7}
# 261/10000 (2%)	 {'predicted': 'been', 'actual': 'been', 'mask_idx': 78}
# 262/10000 (2%)	 {'predicted': 'and', 'actual': 'and', 'mask_idx': 87}
# 263/10000 (2%)	 {'predicted': 'rock', 'actual': 'rock', 'mask_idx': 37}
# 264/10000 (2%)	 {'predicted': '"', 'actual': '=', 'mask_idx': 10}
# 265/10000 (2%)	 {'predicted': 'looking', 'actual': 'looking', 'mask_idx': 32}
# 266/10000 (2%)	 {'predicted': 'festival', 'actual': 'second', 'mask_idx': 30}
# 267/10000 (2%)	 {'predicted': 'ft', 'actual': 'yards', 'mask_idx': 30}
# 268/10000 (2%)	 {'predicted': '.', 'actual': '=', 'mask_idx': 9}
# 269/10000 (2%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 15}
# 270/10000 (2%)	 {'predicted': 'no', 'actual': 'favorable', 'mask_idx': 56}
# 271/10000 (2%)	 {'predicted': 'named', 'actual': 'named', 'mask_idx': 69}
# 272/10000 (2%)	 {'predicted': 'nations', 'actual': 'nations', 'mask_idx': 87}
# 273/10000 (2%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 61}
# 274/10000 (2%)	 {'predicted': 'head', 'actual': 'front', 'mask_idx': 210}
# 275/10000 (2%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 1}
# 276/10000 (2%)	 {'predicted': "'", 'actual': "'", 'mask_idx': 121}
# 277/10000 (2%)	 {'predicted': 'unable', 'actual': 'unable', 'mask_idx': 71}
# 278/10000 (2%)	 {'predicted': 'out', 'actual': 'out', 'mask_idx': 160}
# 279/10000 (2%)	 {'predicted': 'it', 'actual': 'it', 'mask_idx': 104}
# 280/10000 (2%)	 {'predicted': 'joined', 'actual': 'aided', 'mask_idx': 180}
# 281/10000 (2%)	 {'predicted': 'and', 'actual': 'and', 'mask_idx': 38}
# 282/10000 (2%)	 {'predicted': 'populous', 'actual': 'populous', 'mask_idx': 27}
# 283/10000 (2%)	 {'predicted': '"', 'actual': 'own', 'mask_idx': 65}
# 284/10000 (2%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 160}
# 285/10000 (2%)	 {'predicted': 'film', 'actual': 'film', 'mask_idx': 5}
# 286/10000 (2%)	 {'predicted': 'who', 'actual': '<', 'mask_idx': 75}
# 287/10000 (2%)	 {'predicted': 'support', 'actual': 'control', 'mask_idx': 12}
# 288/10000 (2%)	 {'predicted': 'making', 'actual': 'making', 'mask_idx': 292}
# 289/10000 (2%)	 {'predicted': 'team', 'actual': 'bulldogs', 'mask_idx': 44}
# 290/10000 (2%)	 {'predicted': 'about', 'actual': 'until', 'mask_idx': 74}
# 291/10000 (2%)	 {'predicted': 'unlike', 'actual': 'unlike', 'mask_idx': 246}
# 292/10000 (2%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 3}
# 293/10000 (2%)	 {'predicted': 'means', 'actual': 'attack', 'mask_idx': 110}
# 294/10000 (2%)	 {'predicted': 'of', 'actual': 'of', 'mask_idx': 119}
# 295/10000 (2%)	 {'predicted': 'three', 'actual': '90', 'mask_idx': 111}
# 296/10000 (2%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 75}
# 297/10000 (2%)	 {'predicted': 'and', 'actual': 'and', 'mask_idx': 111}
# 298/10000 (2%)	 {'predicted': 'were', 'actual': 'were', 'mask_idx': 56}
# 299/10000 (2%)	 {'predicted': 'collection', 'actual': 'collection', 'mask_idx': 29}
# 300/10000 (3%)	 {'predicted': 'units', 'actual': 'seventeen', 'mask_idx': 4}
# 301/10000 (3%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 38}
# 302/10000 (3%)	 {'predicted': 'he', 'actual': 'he', 'mask_idx': 19}
# 303/10000 (3%)	 {'predicted': 'assumes', 'actual': 'concludes', 'mask_idx': 94}
# 304/10000 (3%)	 {'predicted': 'was', 'actual': 'was', 'mask_idx': 82}
# 305/10000 (3%)	 {'predicted': 'by', 'actual': 'by', 'mask_idx': 16}
# 306/10000 (3%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 82}
# 307/10000 (3%)	 {'predicted': '##a', 'actual': 'club', 'mask_idx': 3}
# 308/10000 (3%)	 {'predicted': 'he', 'actual': 'he', 'mask_idx': 12}
# 309/10000 (3%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 24}
# 310/10000 (3%)	 {'predicted': 'spin', 'actual': 'non', 'mask_idx': 58}
# 311/10000 (3%)	 {'predicted': 'to', 'actual': 'to', 'mask_idx': 9}
# 312/10000 (3%)	 {'predicted': 'and', 'actual': 'and', 'mask_idx': 62}
# 313/10000 (3%)	 {'predicted': '.', 'actual': 'as', 'mask_idx': 112}
# 314/10000 (3%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 116}
# 315/10000 (3%)	 {'predicted': 'provided', 'actual': 'provided', 'mask_idx': 129}
# 316/10000 (3%)	 {'predicted': ',', 'actual': '.', 'mask_idx': 145}
# 317/10000 (3%)	 {'predicted': 'had', 'actual': 'had', 'mask_idx': 50}
# 318/10000 (3%)	 {'predicted': 'version', 'actual': 'version', 'mask_idx': 24}
# 319/10000 (3%)	 {'predicted': '.', 'actual': 'of', 'mask_idx': 30}
# 320/10000 (3%)	 {'predicted': 'hill', 'actual': 'hill', 'mask_idx': 128}
# 321/10000 (3%)	 {'predicted': 'number', 'actual': 'number', 'mask_idx': 6}
# 322/10000 (3%)	 {'predicted': 'designed', 'actual': 'designed', 'mask_idx': 167}
# 323/10000 (3%)	 {'predicted': 'knots', 'actual': 'knots', 'mask_idx': 61}
# 324/10000 (3%)	 {'predicted': 'species', 'actual': ',', 'mask_idx': 69}
# 325/10000 (3%)	 {'predicted': 'in', 'actual': 'on', 'mask_idx': 52}
# 326/10000 (3%)	 {'predicted': 'write', 'actual': 'publish', 'mask_idx': 31}
# 327/10000 (3%)	 {'predicted': 'eddie', 'actual': 'he', 'mask_idx': 69}
# 328/10000 (3%)	 {'predicted': 'ancient', 'actual': 'ancient', 'mask_idx': 126}
# 329/10000 (3%)	 {'predicted': 'and', 'actual': 'and', 'mask_idx': 104}
# 330/10000 (3%)	 {'predicted': 'states', 'actual': 'states', 'mask_idx': 23}
# 331/10000 (3%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 266}
# 332/10000 (3%)	 {'predicted': 'by', 'actual': 'by', 'mask_idx': 54}
# 333/10000 (3%)	 {'predicted': 'and', 'actual': 'and', 'mask_idx': 44}
# 334/10000 (3%)	 {'predicted': 'a', 'actual': 'native', 'mask_idx': 75}
# 335/10000 (3%)	 {'predicted': 'while', 'actual': 'while', 'mask_idx': 16}
# 336/10000 (3%)	 {'predicted': 'that', 'actual': 'that', 'mask_idx': 46}
# 337/10000 (3%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 189}
# 338/10000 (3%)	 {'predicted': 'the', 'actual': 'spanish', 'mask_idx': 107}
# 339/10000 (3%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 30}
# 340/10000 (3%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 46}
# 341/10000 (3%)	 {'predicted': 'and', 'actual': 'and', 'mask_idx': 67}
# 342/10000 (3%)	 {'predicted': '"', 'actual': '"', 'mask_idx': 57}
# 343/10000 (3%)	 {'predicted': '.', 'actual': 'reported', 'mask_idx': 105}
# 344/10000 (3%)	 {'predicted': ':', 'actual': 'firstly', 'mask_idx': 211}
# 345/10000 (3%)	 {'predicted': 'returned', 'actual': 'returned', 'mask_idx': 44}
# 346/10000 (3%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 11}
# 347/10000 (3%)	 {'predicted': 'had', 'actual': 'mysteriously', 'mask_idx': 287}
# 348/10000 (3%)	 {'predicted': 'large', 'actual': 'small', 'mask_idx': 90}
# 349/10000 (3%)	 {'predicted': 'he', 'actual': 'he', 'mask_idx': 81}
# 350/10000 (3%)	 {'predicted': '-', 'actual': '@', 'mask_idx': 10}
# 351/10000 (3%)	 {'predicted': 'have', 'actual': 'have', 'mask_idx': 25}
# 352/10000 (3%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 56}
# 353/10000 (3%)	 {'predicted': 'making', 'actual': 'making', 'mask_idx': 22}
# 354/10000 (3%)	 {'predicted': 'to', 'actual': 'to', 'mask_idx': 35}
# 355/10000 (3%)	 {'predicted': 'from', 'actual': 'to', 'mask_idx': 58}
# 356/10000 (3%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 88}
# 357/10000 (3%)	 {'predicted': 'property', 'actual': 'assets', 'mask_idx': 125}
# 358/10000 (3%)	 {'predicted': 'indeed', 'actual': 'however', 'mask_idx': 21}
# 359/10000 (3%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 14}
# 360/10000 (3%)	 {'predicted': 'achieved', 'actual': 'sought', 'mask_idx': 70}
# 361/10000 (3%)	 {'predicted': 'without', 'actual': 'without', 'mask_idx': 6}
# 362/10000 (3%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 8}
# 363/10000 (3%)	 {'predicted': 'influence', 'actual': 'expenses', 'mask_idx': 9}
# 364/10000 (3%)	 {'predicted': '1', 'actual': '8', 'mask_idx': 36}
# 365/10000 (3%)	 {'predicted': '.', 'actual': '8', 'mask_idx': 5}
# 366/10000 (3%)	 {'predicted': 'published', 'actual': 'submitted', 'mask_idx': 25}
# 367/10000 (3%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 23}
# 368/10000 (3%)	 {'predicted': '!', 'actual': 'eddie', 'mask_idx': 79}
# 369/10000 (3%)	 {'predicted': 'the', 'actual': 'a', 'mask_idx': 50}
# 370/10000 (3%)	 {'predicted': 'city', 'actual': 'country', 'mask_idx': 63}
# 371/10000 (3%)	 {'predicted': 'intervention', 'actual': '<', 'mask_idx': 46}
# 372/10000 (3%)	 {'predicted': 'back', 'actual': 'back', 'mask_idx': 78}
# 373/10000 (3%)	 {'predicted': 'which', 'actual': 'which', 'mask_idx': 77}
# 374/10000 (3%)	 {'predicted': '"', 'actual': '"', 'mask_idx': 199}
# 375/10000 (3%)	 {'predicted': 'de', 'actual': 'de', 'mask_idx': 14}
# 376/10000 (3%)	 {'predicted': 'in', 'actual': 'of', 'mask_idx': 76}
# 377/10000 (3%)	 {'predicted': 'african', 'actual': 'african', 'mask_idx': 64}
# 378/10000 (3%)	 {'predicted': 'been', 'actual': 'been', 'mask_idx': 7}
# 379/10000 (3%)	 {'predicted': '2', 'actual': 'two', 'mask_idx': 16}
# 380/10000 (3%)	 {'predicted': 'taking', 'actual': 'putting', 'mask_idx': 10}
# 381/10000 (3%)	 {'predicted': 'two', 'actual': '1842', 'mask_idx': 71}
# 382/10000 (3%)	 {'predicted': '"', 'actual': '"', 'mask_idx': 136}
# 383/10000 (3%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 160}
# 384/10000 (3%)	 {'predicted': '.', 'actual': '<', 'mask_idx': 0}
# 385/10000 (3%)	 {'predicted': 'was', 'actual': 'was', 'mask_idx': 30}
# 386/10000 (3%)	 {'predicted': 'they', 'actual': 'does', 'mask_idx': 30}
# 387/10000 (3%)	 {'predicted': '-', 'actual': 'match', 'mask_idx': 57}
# 388/10000 (3%)	 {'predicted': 'difficult', 'actual': 'difficult', 'mask_idx': 130}
# 389/10000 (3%)	 {'predicted': 'pass', 'actual': 'stop', 'mask_idx': 33}
# 390/10000 (3%)	 {'predicted': 'all', 'actual': 'all', 'mask_idx': 52}
# 391/10000 (3%)	 {'predicted': 'a', 'actual': 'a', 'mask_idx': 147}
# 392/10000 (3%)	 {'predicted': 'small', 'actual': 'converted', 'mask_idx': 6}
# 393/10000 (3%)	 {'predicted': 'fully', 'actual': '<', 'mask_idx': 68}
# 394/10000 (3%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 44}
# 395/10000 (3%)	 {'predicted': 'elements', 'actual': 'elements', 'mask_idx': 12}
# 396/10000 (3%)	 {'predicted': '.', 'actual': 'optical', 'mask_idx': 0}
# 397/10000 (3%)	 {'predicted': 'planned', 'actual': 'proceeded', 'mask_idx': 96}
# 398/10000 (3%)	 {'predicted': '##nic', 'actual': "'", 'mask_idx': 28}
# 399/10000 (3%)	 {'predicted': 'restaurants', 'actual': 'houses', 'mask_idx': 146}
# 400/10000 (4%)	 {'predicted': 'typhoon', 'actual': 'typhoon', 'mask_idx': 32}
# 401/10000 (4%)	 {'predicted': 'was', 'actual': 'decided', 'mask_idx': 32}
# 402/10000 (4%)	 {'predicted': 'owed', 'actual': 'owed', 'mask_idx': 54}
# 403/10000 (4%)	 {'predicted': 'with', 'actual': 'with', 'mask_idx': 265}
# 404/10000 (4%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 160}
# 405/10000 (4%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 97}
# 406/10000 (4%)	 {'predicted': ',', 'actual': 'workplace', 'mask_idx': 39}
# 407/10000 (4%)	 {'predicted': 'also', 'actual': 'although', 'mask_idx': 115}
# 408/10000 (4%)	 {'predicted': 'associated', 'actual': 'sculpted', 'mask_idx': 79}
# 409/10000 (4%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 214}
# 410/10000 (4%)	 {'predicted': 'been', 'actual': 'been', 'mask_idx': 230}
# 411/10000 (4%)	 {'predicted': 'he', 'actual': 'he', 'mask_idx': 33}
# 412/10000 (4%)	 {'predicted': 'salsa', 'actual': 'salsa', 'mask_idx': 251}
# 413/10000 (4%)	 {'predicted': 'and', 'actual': ',', 'mask_idx': 26}
# 414/10000 (4%)	 {'predicted': 'day', 'actual': 'day', 'mask_idx': 9}
# 415/10000 (4%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 37}
# 416/10000 (4%)	 {'predicted': '4', 'actual': '2', 'mask_idx': 53}
# 417/10000 (4%)	 {'predicted': 'tour', 'actual': 'tour', 'mask_idx': 33}
# 418/10000 (4%)	 {'predicted': 'new', 'actual': '<', 'mask_idx': 62}
# 419/10000 (4%)	 {'predicted': 'tanks', 'actual': '<', 'mask_idx': 28}
# 420/10000 (4%)	 {'predicted': '2009', 'actual': '2007', 'mask_idx': 99}
# 421/10000 (4%)	 {'predicted': 'light', 'actual': 'light', 'mask_idx': 245}
# 422/10000 (4%)	 {'predicted': '"', 'actual': '"', 'mask_idx': 28}
# 423/10000 (4%)	 {'predicted': 'is', 'actual': 'is', 'mask_idx': 35}
# 424/10000 (4%)	 {'predicted': ')', 'actual': '<', 'mask_idx': 0}
# 425/10000 (4%)	 {'predicted': 'a', 'actual': 'a', 'mask_idx': 206}
# 426/10000 (4%)	 {'predicted': 'rural', 'actual': 'fishing', 'mask_idx': 39}
# 427/10000 (4%)	 {'predicted': '2005', 'actual': 'the', 'mask_idx': 53}
# 428/10000 (4%)	 {'predicted': 'mostly', 'actual': 'mostly', 'mask_idx': 83}
# 429/10000 (4%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 128}
# 430/10000 (4%)	 {'predicted': 'authority', 'actual': 'incorporated', 'mask_idx': 90}
# 431/10000 (4%)	 {'predicted': 'end', 'actual': 'conclusion', 'mask_idx': 152}
# 432/10000 (4%)	 {'predicted': 'army', 'actual': 'army', 'mask_idx': 95}
# 433/10000 (4%)	 {'predicted': 'knowledge', 'actual': 'knowledge', 'mask_idx': 33}
# 434/10000 (4%)	 {'predicted': '"', 'actual': 'wooden', 'mask_idx': 24}
# 435/10000 (4%)	 {'predicted': 'in', 'actual': 'in', 'mask_idx': 136}
# 436/10000 (4%)	 {'predicted': 'latin', 'actual': 'latin', 'mask_idx': 23}
# 437/10000 (4%)	 {'predicted': 'howard', 'actual': 'grant', 'mask_idx': 176}
# 438/10000 (4%)	 {'predicted': 'led', 'actual': 'led', 'mask_idx': 59}
# 439/10000 (4%)	 {'predicted': 'the', 'actual': 'quick', 'mask_idx': 1}
# 440/10000 (4%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 63}
# 441/10000 (4%)	 {'predicted': 'the', 'actual': 'local', 'mask_idx': 30}
# 442/10000 (4%)	 {'predicted': 'pool', 'actual': 'the', 'mask_idx': 157}
# 443/10000 (4%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 48}
# 444/10000 (4%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 142}
# 445/10000 (4%)	 {'predicted': 'of', 'actual': 'of', 'mask_idx': 27}
# 446/10000 (4%)	 {'predicted': 'closed', 'actual': 'came', 'mask_idx': 75}
# 447/10000 (4%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 128}
# 448/10000 (4%)	 {'predicted': 'mesa', 'actual': '<', 'mask_idx': 33}
# 449/10000 (4%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 273}
# 450/10000 (4%)	 {'predicted': 'airport', 'actual': 'airport', 'mask_idx': 116}
# 451/10000 (4%)	 {'predicted': 'past', 'actual': 'prior', 'mask_idx': 22}
# 452/10000 (4%)	 {'predicted': '(', 'actual': '(', 'mask_idx': 41}
# 453/10000 (4%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 13}
# 454/10000 (4%)	 {'predicted': 'isle', 'actual': 'isle', 'mask_idx': 24}
# 455/10000 (4%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 141}
# 456/10000 (4%)	 {'predicted': 'of', 'actual': 'of', 'mask_idx': 28}
# 457/10000 (4%)	 {'predicted': 'and', 'actual': 'and', 'mask_idx': 36}
# 458/10000 (4%)	 {'predicted': 'door', 'actual': 'vault', 'mask_idx': 104}
# 459/10000 (4%)	 {'predicted': 'following', 'actual': 'after', 'mask_idx': 5}
# 460/10000 (4%)	 {'predicted': 'it', 'actual': 'landfall', 'mask_idx': 17}
# 461/10000 (4%)	 {'predicted': 'of', 'actual': 'of', 'mask_idx': 78}
# 462/10000 (4%)	 {'predicted': 'him', 'actual': '<', 'mask_idx': 71}
# 463/10000 (4%)	 {'predicted': '-', 'actual': '@', 'mask_idx': 63}
# 464/10000 (4%)	 {'predicted': 'a', 'actual': 'a', 'mask_idx': 17}
# 465/10000 (4%)	 {'predicted': 'and', 'actual': 'and', 'mask_idx': 9}
# 466/10000 (4%)	 {'predicted': 'of', 'actual': 'rene', 'mask_idx': 48}
# 467/10000 (4%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 59}
# 468/10000 (4%)	 {'predicted': 'language', 'actual': '<', 'mask_idx': 39}
# 469/10000 (4%)	 {'predicted': 'and', 'actual': 'and', 'mask_idx': 25}
# 470/10000 (4%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 79}
# 471/10000 (4%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 128}
# 472/10000 (4%)	 {'predicted': 'that', 'actual': 'that', 'mask_idx': 54}
# 473/10000 (4%)	 {'predicted': 'away', 'actual': 'away', 'mask_idx': 146}
# 474/10000 (4%)	 {'predicted': '"', 'actual': 'major', 'mask_idx': 4}
# 475/10000 (4%)	 {'predicted': 'his', 'actual': 'the', 'mask_idx': 144}
# 476/10000 (4%)	 {'predicted': 'able', 'actual': 'built', 'mask_idx': 104}
# 477/10000 (4%)	 {'predicted': 'of', 'actual': 'of', 'mask_idx': 34}
# 478/10000 (4%)	 {'predicted': 'been', 'actual': 'been', 'mask_idx': 109}
# 479/10000 (4%)	 {'predicted': '##s', 'actual': 'bombers', 'mask_idx': 97}
# 480/10000 (4%)	 {'predicted': 'renaming', 'actual': 'pitch', 'mask_idx': 207}
# 481/10000 (4%)	 {'predicted': 'work', 'actual': 'language', 'mask_idx': 125}
# 482/10000 (4%)	 {'predicted': 'and', 'actual': 'on', 'mask_idx': 17}
# 483/10000 (4%)	 {'predicted': 'present', 'actual': '1880s', 'mask_idx': 5}
# 484/10000 (4%)	 {'predicted': 'as', 'actual': 'by', 'mask_idx': 69}
# 485/10000 (4%)	 {'predicted': 'dates', 'actual': 'dates', 'mask_idx': 143}
# 486/10000 (4%)	 {'predicted': 'even', 'actual': '<', 'mask_idx': 144}
# 487/10000 (4%)	 {'predicted': ',', 'actual': '—', 'mask_idx': 78}
# 488/10000 (4%)	 {'predicted': 'infantry', 'actual': 'infantry', 'mask_idx': 85}
# 489/10000 (4%)	 {'predicted': '-', 'actual': 'by', 'mask_idx': 173}
# 490/10000 (4%)	 {'predicted': '"', 'actual': '"', 'mask_idx': 68}
# 491/10000 (4%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 40}
# 492/10000 (4%)	 {'predicted': '(', 'actual': 'no', 'mask_idx': 17}
# 493/10000 (4%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 83}
# 494/10000 (4%)	 {'predicted': 'the', 'actual': 'he', 'mask_idx': 228}
# 495/10000 (4%)	 {'predicted': 'years', 'actual': 'years', 'mask_idx': 168}
# 496/10000 (4%)	 {'predicted': 'formed', 'actual': 'formed', 'mask_idx': 20}
# 497/10000 (4%)	 {'predicted': 'of', 'actual': 'of', 'mask_idx': 102}
# 498/10000 (4%)	 {'predicted': 'front', 'actual': 'coast', 'mask_idx': 20}
# 499/10000 (4%)	 {'predicted': 'of', 'actual': 'of', 'mask_idx': 128}
# 500/10000 (5%)	 {'predicted': 'brigade', 'actual': 'regiment', 'mask_idx': 31}
# 501/10000 (5%)	 {'predicted': 'single', 'actual': 'feature', 'mask_idx': 26}
# 502/10000 (5%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 73}
# 503/10000 (5%)	 {'predicted': 'bombardier', 'actual': '<', 'mask_idx': 125}
# 504/10000 (5%)	 {'predicted': 'to', 'actual': 'to', 'mask_idx': 102}
# 505/10000 (5%)	 {'predicted': '"', 'actual': '"', 'mask_idx': 58}
# 506/10000 (5%)	 {'predicted': 'from', 'actual': 'in', 'mask_idx': 13}
# 507/10000 (5%)	 {'predicted': 'develop', 'actual': 'develop', 'mask_idx': 34}
# 508/10000 (5%)	 {'predicted': '.', 'actual': 'this', 'mask_idx': 0}
# 509/10000 (5%)	 {'predicted': 'particular', 'actual': 'specific', 'mask_idx': 27}
# 510/10000 (5%)	 {'predicted': 'of', 'actual': 'of', 'mask_idx': 30}
# 511/10000 (5%)	 {'predicted': 'and', 'actual': 'and', 'mask_idx': 32}
# 512/10000 (5%)	 {'predicted': 'typical', 'actual': 'steam', 'mask_idx': 13}
# 513/10000 (5%)	 {'predicted': 'in', 'actual': 'even', 'mask_idx': 42}
# 514/10000 (5%)	 {'predicted': 'received', 'actual': 'received', 'mask_idx': 152}
# 515/10000 (5%)	 {'predicted': 'so', 'actual': 'very', 'mask_idx': 60}
# 516/10000 (5%)	 {'predicted': 'torpedoes', 'actual': 'mines', 'mask_idx': 74}
# 517/10000 (5%)	 {'predicted': 'torpedo', 'actual': 'training', 'mask_idx': 44}
# 518/10000 (5%)	 {'predicted': 'been', 'actual': 'remained', 'mask_idx': 51}
# 519/10000 (5%)	 {'predicted': 'halted', 'actual': 'few', 'mask_idx': 15}
# 520/10000 (5%)	 {'predicted': ',', 'actual': '<', 'mask_idx': 101}
# 521/10000 (5%)	 {'predicted': 'brought', 'actual': 'lost', 'mask_idx': 12}
# 522/10000 (5%)	 {'predicted': 'horizontal', 'actual': 'heavy', 'mask_idx': 75}
# 523/10000 (5%)	 {'predicted': 'and', 'actual': 'and', 'mask_idx': 47}
# 524/10000 (5%)	 {'predicted': 'many', 'actual': '<', 'mask_idx': 3}
# 525/10000 (5%)	 {'predicted': '.', 'actual': '100', 'mask_idx': 11}
# 526/10000 (5%)	 {'predicted': 'brother', 'actual': 'agent', 'mask_idx': 9}
# 527/10000 (5%)	 {'predicted': 'no', 'actual': 'no', 'mask_idx': 70}
# 528/10000 (5%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 110}
# 529/10000 (5%)	 {'predicted': 'five', 'actual': 'three', 'mask_idx': 37}
# 530/10000 (5%)	 {'predicted': 'he', 'actual': '<', 'mask_idx': 51}
# 531/10000 (5%)	 {'predicted': 'the', 'actual': 'a', 'mask_idx': 78}
# 532/10000 (5%)	 {'predicted': 'is', 'actual': 'is', 'mask_idx': 2}
# 533/10000 (5%)	 {'predicted': 'transport', 'actual': 'transport', 'mask_idx': 117}
# 534/10000 (5%)	 {'predicted': 'lost', 'actual': 'lost', 'mask_idx': 37}
# 535/10000 (5%)	 {'predicted': '5', 'actual': 'three', 'mask_idx': 44}
# 536/10000 (5%)	 {'predicted': 'the', 'actual': 'operational', 'mask_idx': 135}
# 537/10000 (5%)	 {'predicted': ',', 'actual': 'sr', 'mask_idx': 210}
# 538/10000 (5%)	 {'predicted': 'lowell', 'actual': 'pound', 'mask_idx': 290}
# 539/10000 (5%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 61}
# 540/10000 (5%)	 {'predicted': ',', 'actual': 'lead', 'mask_idx': 13}
# 541/10000 (5%)	 {'predicted': '.', 'actual': 'the', 'mask_idx': 0}
# 542/10000 (5%)	 {'predicted': 'were', 'actual': 'were', 'mask_idx': 96}
# 543/10000 (5%)	 {'predicted': 'to', 'actual': 'to', 'mask_idx': 91}
# 544/10000 (5%)	 {'predicted': ',', 'actual': '@', 'mask_idx': 70}
# 545/10000 (5%)	 {'predicted': '.', 'actual': '@', 'mask_idx': 122}
# 546/10000 (5%)	 {'predicted': 'of', 'actual': 'of', 'mask_idx': 7}
# 547/10000 (5%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 233}
# 548/10000 (5%)	 {'predicted': 'version', 'actual': 'version', 'mask_idx': 8}
# 549/10000 (5%)	 {'predicted': 'against', 'actual': 'against', 'mask_idx': 43}
# 550/10000 (5%)	 {'predicted': 'speeches', 'actual': 'suggestions', 'mask_idx': 45}
# 551/10000 (5%)	 {'predicted': 'hospital', 'actual': '<', 'mask_idx': 76}
# 552/10000 (5%)	 {'predicted': '13', 'actual': '13', 'mask_idx': 72}
# 553/10000 (5%)	 {'predicted': 'ballad', 'actual': 'pop', 'mask_idx': 123}
# 554/10000 (5%)	 {'predicted': 'the', 'actual': 'its', 'mask_idx': 122}
# 555/10000 (5%)	 {'predicted': 'and', 'actual': 'and', 'mask_idx': 85}
# 556/10000 (5%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 62}
# 557/10000 (5%)	 {'predicted': 'not', 'actual': '<', 'mask_idx': 14}
# 558/10000 (5%)	 {'predicted': 'c', 'actual': 'c', 'mask_idx': 9}
# 559/10000 (5%)	 {'predicted': 'of', 'actual': 'of', 'mask_idx': 51}
# 560/10000 (5%)	 {'predicted': 'matt', 'actual': '<', 'mask_idx': 31}
# 561/10000 (5%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 63}
# 562/10000 (5%)	 {'predicted': 'to', 'actual': 'to', 'mask_idx': 189}
# 563/10000 (5%)	 {'predicted': 'in', 'actual': 'in', 'mask_idx': 15}
# 564/10000 (5%)	 {'predicted': 'robert', 'actual': 'shane', 'mask_idx': 127}
# 565/10000 (5%)	 {'predicted': 'changed', 'actual': 'began', 'mask_idx': 55}
# 566/10000 (5%)	 {'predicted': '[UNK]', 'actual': 'sony', 'mask_idx': 129}
# 567/10000 (5%)	 {'predicted': 'hope', 'actual': '<', 'mask_idx': 8}
# 568/10000 (5%)	 {'predicted': 'are', 'actual': 'show', 'mask_idx': 86}
# 569/10000 (5%)	 {'predicted': 'groups', 'actual': 'groups', 'mask_idx': 74}
# 570/10000 (5%)	 {'predicted': 'time', 'actual': 'time', 'mask_idx': 99}
# 571/10000 (5%)	 {'predicted': 'began', 'actual': 'began', 'mask_idx': 5}
# 572/10000 (5%)	 {'predicted': ',', 'actual': '<', 'mask_idx': 17}
# 573/10000 (5%)	 {'predicted': '.', 'actual': '<', 'mask_idx': 0}
# 574/10000 (5%)	 {'predicted': 'style', 'actual': 'style', 'mask_idx': 106}
# 575/10000 (5%)	 {'predicted': 'late', 'actual': 'middle', 'mask_idx': 13}
# 576/10000 (5%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 161}
# 577/10000 (5%)	 {'predicted': ',', 'actual': 'for', 'mask_idx': 30}
# 578/10000 (5%)	 {'predicted': 'cup', 'actual': 'cup', 'mask_idx': 155}
# 579/10000 (5%)	 {'predicted': 'the', 'actual': '<', 'mask_idx': 147}
# 580/10000 (5%)	 {'predicted': '50', 'actual': '800', 'mask_idx': 105}
# 581/10000 (5%)	 {'predicted': 'city', 'actual': 'area', 'mask_idx': 76}
# 582/10000 (5%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 81}
# 583/10000 (5%)	 {'predicted': '4th', 'actual': '19th', 'mask_idx': 324}
# 584/10000 (5%)	 {'predicted': '.', 'actual': 'to', 'mask_idx': 0}
# 585/10000 (5%)	 {'predicted': 'to', 'actual': 'to', 'mask_idx': 27}
# 586/10000 (5%)	 {'predicted': 'late', 'actual': 'late', 'mask_idx': 36}
# 587/10000 (5%)	 {'predicted': 'management', 'actual': 'finance', 'mask_idx': 73}
# 588/10000 (5%)	 {'predicted': 'his', 'actual': 'his', 'mask_idx': 11}
# 589/10000 (5%)	 {'predicted': 'armed', 'actual': 'auxiliary', 'mask_idx': 32}
# 590/10000 (5%)	 {'predicted': 'city', 'actual': 'university', 'mask_idx': 64}
# 591/10000 (5%)	 {'predicted': ')', 'actual': ')', 'mask_idx': 27}
# 592/10000 (5%)	 {'predicted': 'other', 'actual': 'earliest', 'mask_idx': 11}
# 593/10000 (5%)	 {'predicted': 'his', 'actual': 'his', 'mask_idx': 29}
# 594/10000 (5%)	 {'predicted': 'hundred', 'actual': '140', 'mask_idx': 41}
# 595/10000 (5%)	 {'predicted': 'round', 'actual': 'season', 'mask_idx': 80}
# 596/10000 (5%)	 {'predicted': 'the', 'actual': 'spanish', 'mask_idx': 36}
# 597/10000 (5%)	 {'predicted': 'began', 'actual': 'wanted', 'mask_idx': 7}
# 598/10000 (5%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 156}
# 599/10000 (5%)	 {'predicted': '(', 'actual': 'june', 'mask_idx': 23}
# 600/10000 (6%)	 {'predicted': 'that', 'actual': 'that', 'mask_idx': 13}
# 601/10000 (6%)	 {'predicted': 'finally', 'actual': 'eventually', 'mask_idx': 38}
# 602/10000 (6%)	 {'predicted': 'by', 'actual': 'by', 'mask_idx': 98}
# 603/10000 (6%)	 {'predicted': 'service', 'actual': 'display', 'mask_idx': 14}
# 604/10000 (6%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 15}
# 605/10000 (6%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 11}
# 606/10000 (6%)	 {'predicted': '27', 'actual': '15', 'mask_idx': 2}
# 607/10000 (6%)	 {'predicted': 'ny', 'actual': 'cr', 'mask_idx': 136}
# 608/10000 (6%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 71}
# 609/10000 (6%)	 {'predicted': 'international', 'actual': 'mexico', 'mask_idx': 83}
# 610/10000 (6%)	 {'predicted': 'in', 'actual': '<', 'mask_idx': 2}
# 611/10000 (6%)	 {'predicted': 'similar', 'actual': 'cameo', 'mask_idx': 9}
# 612/10000 (6%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 75}
# 613/10000 (6%)	 {'predicted': '-', 'actual': '(', 'mask_idx': 5}
# 614/10000 (6%)	 {'predicted': 'repaired', 'actual': 'rebuilt', 'mask_idx': 138}
# 615/10000 (6%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 6}
# 616/10000 (6%)	 {'predicted': 'did', 'actual': 'did', 'mask_idx': 83}
# 617/10000 (6%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 100}
# 618/10000 (6%)	 {'predicted': 'warfare', 'actual': 'warfare', 'mask_idx': 30}
# 619/10000 (6%)	 {'predicted': 'at', 'actual': 'viewed', 'mask_idx': 43}
# 620/10000 (6%)	 {'predicted': 'father', 'actual': 'friend', 'mask_idx': 136}
# 621/10000 (6%)	 {'predicted': '.', 'actual': 'this', 'mask_idx': 0}
# 622/10000 (6%)	 {'predicted': 'and', 'actual': 'and', 'mask_idx': 26}
# 623/10000 (6%)	 {'predicted': '.', 'actual': 'many', 'mask_idx': 0}
# 624/10000 (6%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 8}
# 625/10000 (6%)	 {'predicted': 'his', 'actual': 'the', 'mask_idx': 23}
# 626/10000 (6%)	 {'predicted': ':', 'actual': 'miguel', 'mask_idx': 26}
# 627/10000 (6%)	 {'predicted': 'following', 'actual': 'past', 'mask_idx': 127}
# 628/10000 (6%)	 {'predicted': 'temperature', 'actual': 'temperature', 'mask_idx': 33}
# 629/10000 (6%)	 {'predicted': 'and', 'actual': 'to', 'mask_idx': 129}
# 630/10000 (6%)	 {'predicted': 'olympics', 'actual': 'olympics', 'mask_idx': 27}
# 631/10000 (6%)	 {'predicted': 'order', 'actual': '<', 'mask_idx': 83}
# 632/10000 (6%)	 {'predicted': 'off', 'actual': 'off', 'mask_idx': 44}
# 633/10000 (6%)	 {'predicted': 'for', 'actual': 'for', 'mask_idx': 9}
# 634/10000 (6%)	 {'predicted': 'of', 'actual': 'of', 'mask_idx': 130}
# 635/10000 (6%)	 {'predicted': 'time', 'actual': 'time', 'mask_idx': 67}
# 636/10000 (6%)	 {'predicted': 'september', 'actual': 'may', 'mask_idx': 77}
# 637/10000 (6%)	 {'predicted': 'about', 'actual': 'through', 'mask_idx': 42}
# 638/10000 (6%)	 {'predicted': 'being', 'actual': 'possibly', 'mask_idx': 39}
# 639/10000 (6%)	 {'predicted': 'and', 'actual': 'and', 'mask_idx': 79}
# 640/10000 (6%)	 {'predicted': 'wwe', 'actual': 'simply', 'mask_idx': 35}
# 641/10000 (6%)	 {'predicted': 'high', 'actual': 'charter', 'mask_idx': 82}
# 642/10000 (6%)	 {'predicted': '=', 'actual': '=', 'mask_idx': 17}
# 643/10000 (6%)	 {'predicted': 'other', 'actual': 'contemporary', 'mask_idx': 260}
# 644/10000 (6%)	 {'predicted': 'attacked', 'actual': 'attacked', 'mask_idx': 193}
# 645/10000 (6%)	 {'predicted': 'a', 'actual': 'a', 'mask_idx': 25}
# 646/10000 (6%)	 {'predicted': 'oil', 'actual': 'oil', 'mask_idx': 370}
# 647/10000 (6%)	 {'predicted': 'to', 'actual': 'to', 'mask_idx': 203}
# 648/10000 (6%)	 {'predicted': 'almost', 'actual': 'almost', 'mask_idx': 285}
# 649/10000 (6%)	 {'predicted': 'sent', 'actual': 'brought', 'mask_idx': 194}
# 650/10000 (6%)	 {'predicted': 'it', 'actual': '<', 'mask_idx': 18}
# 651/10000 (6%)	 {'predicted': 'densely', 'actual': 'densely', 'mask_idx': 74}
# 652/10000 (6%)	 {'predicted': 'all', 'actual': 'troops', 'mask_idx': 204}
# 653/10000 (6%)	 {'predicted': 'french', 'actual': 'french', 'mask_idx': 27}
# 654/10000 (6%)	 {'predicted': '1869', 'actual': '1880', 'mask_idx': 54}
# 655/10000 (6%)	 {'predicted': 'are', 'actual': 'are', 'mask_idx': 84}
# 656/10000 (6%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 64}
# 657/10000 (6%)	 {'predicted': 'on', 'actual': 'on', 'mask_idx': 165}
# 658/10000 (6%)	 {'predicted': '2007', 'actual': 'match', 'mask_idx': 145}
# 659/10000 (6%)	 {'predicted': 'also', 'actual': 'included', 'mask_idx': 75}
# 660/10000 (6%)	 {'predicted': 'from', 'actual': 'to', 'mask_idx': 186}
# 661/10000 (6%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 205}
# 662/10000 (6%)	 {'predicted': 'been', 'actual': 'married', 'mask_idx': 2}
# 663/10000 (6%)	 {'predicted': 'united', 'actual': 'united', 'mask_idx': 119}
# 664/10000 (6%)	 {'predicted': 'followed', 'actual': 'got', 'mask_idx': 163}
# 665/10000 (6%)	 {'predicted': 'there', 'actual': 'he', 'mask_idx': 15}
# 666/10000 (6%)	 {'predicted': 'by', 'actual': 'by', 'mask_idx': 142}
# 667/10000 (6%)	 {'predicted': 'other', 'actual': 'monumental', 'mask_idx': 60}
# 668/10000 (6%)	 {'predicted': 'third', 'actual': '<', 'mask_idx': 108}
# 669/10000 (6%)	 {'predicted': 'very', 'actual': 'very', 'mask_idx': 53}
# 670/10000 (6%)	 {'predicted': 'their', 'actual': 'their', 'mask_idx': 241}
# ...
# 9787/10000 (97%)	 {'predicted': 'the', 'actual': '=', 'mask_idx': 3}
# 9788/10000 (97%)	 {'predicted': 'australia', 'actual': '<', 'mask_idx': 38}
# 9789/10000 (97%)	 {'predicted': 'all', 'actual': 'both', 'mask_idx': 247}
# 9790/10000 (97%)	 {'predicted': 'that', 'actual': 'aircraft', 'mask_idx': 92}
# 9791/10000 (97%)	 {'predicted': '"', 'actual': 'struggles', 'mask_idx': 6}
# 9792/10000 (97%)	 {'predicted': 'commentary', 'actual': 'audio', 'mask_idx': 20}
# 9793/10000 (97%)	 {'predicted': 'stories', 'actual': 'story', 'mask_idx': 122}
# 9794/10000 (97%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 34}
# 9795/10000 (97%)	 {'predicted': 'wwe', 'actual': 'wwe', 'mask_idx': 73}
# 9796/10000 (97%)	 {'predicted': 'cinematography', 'actual': 'direction', 'mask_idx': 149}
# 9797/10000 (97%)	 {'predicted': 'member', 'actual': 'member', 'mask_idx': 29}
# 9798/10000 (97%)	 {'predicted': 'first', 'actual': 'first', 'mask_idx': 145}
# 9799/10000 (97%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 14}
# 9800/10000 (98%)	 {'predicted': '.', 'actual': ',', 'mask_idx': 8}
# 9801/10000 (98%)	 {'predicted': 'own', 'actual': '2008', 'mask_idx': 200}
# 9802/10000 (98%)	 {'predicted': 'on', 'actual': 'on', 'mask_idx': 145}
# 9803/10000 (98%)	 {'predicted': '@', 'actual': '@', 'mask_idx': 5}
# 9804/10000 (98%)	 {'predicted': '"', 'actual': '"', 'mask_idx': 3}
# 9805/10000 (98%)	 {'predicted': 'physical', 'actual': 'supernatural', 'mask_idx': 40}
# 9806/10000 (98%)	 {'predicted': 'rome', 'actual': '<', 'mask_idx': 15}
# 9807/10000 (98%)	 {'predicted': 'end', 'actual': 'end', 'mask_idx': 102}
# 9808/10000 (98%)	 {'predicted': 'for', 'actual': 'in', 'mask_idx': 105}
# 9809/10000 (98%)	 {'predicted': 'script', 'actual': 'script', 'mask_idx': 123}
# 9810/10000 (98%)	 {'predicted': 'active', 'actual': 'overseas', 'mask_idx': 106}
# 9811/10000 (98%)	 {'predicted': 'intensity', 'actual': 'intensity', 'mask_idx': 98}
# 9812/10000 (98%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 27}
# 9813/10000 (98%)	 {'predicted': '27', 'actual': '25', 'mask_idx': 4}
# 9814/10000 (98%)	 {'predicted': '<', 'actual': '.', 'mask_idx': 109}
# 9815/10000 (98%)	 {'predicted': 'guerrilla', 'actual': 'guerrilla', 'mask_idx': 233}
# 9816/10000 (98%)	 {'predicted': 'commonwealth', 'actual': 'imperial', 'mask_idx': 42}
# 9817/10000 (98%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 11}
# 9818/10000 (98%)	 {'predicted': 'as', 'actual': 'as', 'mask_idx': 132}
# 9819/10000 (98%)	 {'predicted': 'rome', 'actual': 'britain', 'mask_idx': 98}
# 9820/10000 (98%)	 {'predicted': 'first', 'actual': 'pass', 'mask_idx': 22}
# 9821/10000 (98%)	 {'predicted': 'of', 'actual': 'of', 'mask_idx': 2}
# 9822/10000 (98%)	 {'predicted': '1', 'actual': '46', 'mask_idx': 34}
# 9823/10000 (98%)	 {'predicted': 'dvd', 'actual': 'rental', 'mask_idx': 32}
# 9824/10000 (98%)	 {'predicted': 'did', 'actual': 'did', 'mask_idx': 2}
# 9825/10000 (98%)	 {'predicted': 'elementary', 'actual': 'elementary', 'mask_idx': 38}
# 9826/10000 (98%)	 {'predicted': 'greatest', 'actual': 'enabling', 'mask_idx': 103}
# 9827/10000 (98%)	 {'predicted': 'and', 'actual': 'and', 'mask_idx': 90}
# 9828/10000 (98%)	 {'predicted': 'and', 'actual': 'and', 'mask_idx': 99}
# 9829/10000 (98%)	 {'predicted': 'when', 'actual': 'when', 'mask_idx': 13}
# 9830/10000 (98%)	 {'predicted': 'god', 'actual': 'jerusalem', 'mask_idx': 103}
# 9831/10000 (98%)	 {'predicted': 'erie', 'actual': 'niagara', 'mask_idx': 69}
# 9832/10000 (98%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 103}
# 9833/10000 (98%)	 {'predicted': 'areas', 'actual': 'located', 'mask_idx': 133}
# 9834/10000 (98%)	 {'predicted': 'in', 'actual': 'within', 'mask_idx': 119}
# 9835/10000 (98%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 32}
# 9836/10000 (98%)	 {'predicted': 'noon', 'actual': 'ul', 'mask_idx': 71}
# 9837/10000 (98%)	 {'predicted': 'his', 'actual': 'his', 'mask_idx': 79}
# 9838/10000 (98%)	 {'predicted': 'crisis', 'actual': 'flux', 'mask_idx': 27}
# 9839/10000 (98%)	 {'predicted': 'few', 'actual': 'few', 'mask_idx': 119}
# 9840/10000 (98%)	 {'predicted': 'subject', 'actual': 'able', 'mask_idx': 38}
# 9841/10000 (98%)	 {'predicted': 'each', 'actual': 'each', 'mask_idx': 24}
# 9842/10000 (98%)	 {'predicted': 'day', 'actual': 'afternoon', 'mask_idx': 29}
# 9843/10000 (98%)	 {'predicted': ',', 'actual': '.', 'mask_idx': 180}
# 9844/10000 (98%)	 {'predicted': 'downtown', 'actual': 'downtown', 'mask_idx': 75}
# 9845/10000 (98%)	 {'predicted': 'affected', 'actual': 'left', 'mask_idx': 236}
# 9846/10000 (98%)	 {'predicted': 'made', 'actual': 'made', 'mask_idx': 178}
# 9847/10000 (98%)	 {'predicted': 'speaks', 'actual': 'speaks', 'mask_idx': 125}
# 9848/10000 (98%)	 {'predicted': 'lost', 'actual': 'lost', 'mask_idx': 179}
# 9849/10000 (98%)	 {'predicted': 'september', 'actual': 'october', 'mask_idx': 17}
# 9850/10000 (98%)	 {'predicted': 'consecutive', 'actual': 'straight', 'mask_idx': 114}
# 9851/10000 (98%)	 {'predicted': '2', 'actual': '17', 'mask_idx': 140}
# 9852/10000 (98%)	 {'predicted': 'romantic', 'actual': 'victorian', 'mask_idx': 18}
# 9853/10000 (98%)	 {'predicted': 'work', 'actual': 'it', 'mask_idx': 44}
# 9854/10000 (98%)	 {'predicted': 'new', 'actual': 'possible', 'mask_idx': 54}
# 9855/10000 (98%)	 {'predicted': 'and', 'actual': 'seeking', 'mask_idx': 125}
# 9856/10000 (98%)	 {'predicted': 'jim', 'actual': 'jim', 'mask_idx': 67}
# 9857/10000 (98%)	 {'predicted': 'two', 'actual': '1842', 'mask_idx': 71}
# 9858/10000 (98%)	 {'predicted': 'attacks', 'actual': 'attacks', 'mask_idx': 1}
# 9859/10000 (98%)	 {'predicted': 'eastern', 'actual': 'western', 'mask_idx': 59}
# 9860/10000 (98%)	 {'predicted': 'known', 'actual': 'known', 'mask_idx': 33}
# 9861/10000 (98%)	 {'predicted': 'also', 'actual': 'also', 'mask_idx': 53}
# 9862/10000 (98%)	 {'predicted': 'buffer', 'actual': 'precursor', 'mask_idx': 122}
# 9863/10000 (98%)	 {'predicted': 'british', 'actual': 'governor', 'mask_idx': 31}
# 9864/10000 (98%)	 {'predicted': 'harbor', 'actual': 'harbor', 'mask_idx': 41}
# 9865/10000 (98%)	 {'predicted': ',', 'actual': '.', 'mask_idx': 93}
# 9866/10000 (98%)	 {'predicted': 'asia', 'actual': 'asia', 'mask_idx': 40}
# 9867/10000 (98%)	 {'predicted': 'july', 'actual': 'july', 'mask_idx': 49}
# 9868/10000 (98%)	 {'predicted': 'organization', 'actual': 'organization', 'mask_idx': 84}
# 9869/10000 (98%)	 {'predicted': 'dean', 'actual': 'dean', 'mask_idx': 74}
# 9870/10000 (98%)	 {'predicted': ',', 'actual': 'complex', 'mask_idx': 3}
# 9871/10000 (98%)	 {'predicted': 'left', 'actual': 'stopped', 'mask_idx': 145}
# 9872/10000 (98%)	 {'predicted': 'number', 'actual': 'number', 'mask_idx': 94}
# 9873/10000 (98%)	 {'predicted': ':', 'actual': 'contained', 'mask_idx': 6}
# 9874/10000 (98%)	 {'predicted': 'military', 'actual': 'military', 'mask_idx': 145}
# 9875/10000 (98%)	 {'predicted': '3', 'actual': '1', 'mask_idx': 92}
# 9876/10000 (98%)	 {'predicted': '-', 'actual': 'sm', 'mask_idx': 0}
# 9877/10000 (98%)	 {'predicted': 'important', 'actual': 'integral', 'mask_idx': 124}
# 9878/10000 (98%)	 {'predicted': 'way', 'actual': 'story', 'mask_idx': 41}
# 9879/10000 (98%)	 {'predicted': '.', 'actual': ',', 'mask_idx': 4}
# 9880/10000 (98%)	 {'predicted': 'operation', 'actual': 'operation', 'mask_idx': 52}
# 9881/10000 (98%)	 {'predicted': 'a', 'actual': 'a', 'mask_idx': 220}
# 9882/10000 (98%)	 {'predicted': 'and', 'actual': "'", 'mask_idx': 22}
# 9883/10000 (98%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 31}
# 9884/10000 (98%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 21}
# 9885/10000 (98%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 91}
# 9886/10000 (98%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 74}
# 9887/10000 (98%)	 {'predicted': 'to', 'actual': 'to', 'mask_idx': 31}
# 9888/10000 (98%)	 {'predicted': 'fact', 'actual': 'fact', 'mask_idx': 146}
# 9889/10000 (98%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 177}
# 9890/10000 (98%)	 {'predicted': 'god', 'actual': 'hitler', 'mask_idx': 32}
# 9891/10000 (98%)	 {'predicted': 'home', 'actual': 'home', 'mask_idx': 56}
# 9892/10000 (98%)	 {'predicted': 'debut', 'actual': 'debut', 'mask_idx': 169}
# 9893/10000 (98%)	 {'predicted': 'in', 'actual': 'subsequent', 'mask_idx': 1}
# 9894/10000 (98%)	 {'predicted': 'buffalo', 'actual': '<', 'mask_idx': 123}
# 9895/10000 (98%)	 {'predicted': 'created', 'actual': 'married', 'mask_idx': 48}
# 9896/10000 (98%)	 {'predicted': 'the', 'actual': 'his', 'mask_idx': 62}
# 9897/10000 (98%)	 {'predicted': 'more', 'actual': 'more', 'mask_idx': 134}
# 9898/10000 (98%)	 {'predicted': 'in', 'actual': 'during', 'mask_idx': 112}
# 9899/10000 (98%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 106}
# 9900/10000 (99%)	 {'predicted': 'early', 'actual': 'early', 'mask_idx': 9}
# 9901/10000 (99%)	 {'predicted': '=', 'actual': '=', 'mask_idx': 1}
# 9902/10000 (99%)	 {'predicted': 'meanwhile', 'actual': 'meanwhile', 'mask_idx': 36}
# 9903/10000 (99%)	 {'predicted': 'fear', 'actual': 'fear', 'mask_idx': 67}
# 9904/10000 (99%)	 {'predicted': ')', 'actual': ')', 'mask_idx': 36}
# 9905/10000 (99%)	 {'predicted': 'and', 'actual': "'", 'mask_idx': 106}
# 9906/10000 (99%)	 {'predicted': 'storm', 'actual': 'strike', 'mask_idx': 35}
# 9907/10000 (99%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 145}
# 9908/10000 (99%)	 {'predicted': ',', 'actual': 'd', 'mask_idx': 92}
# 9909/10000 (99%)	 {'predicted': '2010', 'actual': '2010', 'mask_idx': 67}
# 9910/10000 (99%)	 {'predicted': 'reptiles', 'actual': '<', 'mask_idx': 16}
# 9911/10000 (99%)	 {'predicted': '.', 'actual': '<', 'mask_idx': 0}
# 9912/10000 (99%)	 {'predicted': 'to', 'actual': 'to', 'mask_idx': 37}
# 9913/10000 (99%)	 {'predicted': 'korean', 'actual': 'korean', 'mask_idx': 99}
# 9914/10000 (99%)	 {'predicted': 'has', 'actual': 'have', 'mask_idx': 19}
# 9915/10000 (99%)	 {'predicted': 'treaty', 'actual': 'treaty', 'mask_idx': 84}
# 9916/10000 (99%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 95}
# 9917/10000 (99%)	 {'predicted': 'holmes', 'actual': 'court', 'mask_idx': 34}
# 9918/10000 (99%)	 {'predicted': 'going', 'actual': 'intended', 'mask_idx': 9}
# 9919/10000 (99%)	 {'predicted': '(', 'actual': '(', 'mask_idx': 82}
# 9920/10000 (99%)	 {'predicted': 'on', 'actual': 'on', 'mask_idx': 13}
# 9921/10000 (99%)	 {'predicted': 'century', 'actual': 'century', 'mask_idx': 4}
# 9922/10000 (99%)	 {'predicted': 'that', 'actual': 'that', 'mask_idx': 26}
# 9923/10000 (99%)	 {'predicted': 'husband', 'actual': '<', 'mask_idx': 35}
# 9924/10000 (99%)	 {'predicted': '"', 'actual': '"', 'mask_idx': 215}
# 9925/10000 (99%)	 {'predicted': 'etc', 'actual': 'respectively', 'mask_idx': 67}
# 9926/10000 (99%)	 {'predicted': 'an', 'actual': 'either', 'mask_idx': 54}
# 9927/10000 (99%)	 {'predicted': 'won', 'actual': 'won', 'mask_idx': 141}
# 9928/10000 (99%)	 {'predicted': ')', 'actual': ')', 'mask_idx': 200}
# 9929/10000 (99%)	 {'predicted': 'how', 'actual': 'how', 'mask_idx': 187}
# 9930/10000 (99%)	 {'predicted': 'after', 'actual': 'after', 'mask_idx': 47}
# 9931/10000 (99%)	 {'predicted': 'tropical', 'actual': 'tropical', 'mask_idx': 46}
# 9932/10000 (99%)	 {'predicted': 'emperor', 'actual': 'emperor', 'mask_idx': 44}
# 9933/10000 (99%)	 {'predicted': '.', 'actual': 'below', 'mask_idx': 31}
# 9934/10000 (99%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 220}
# 9935/10000 (99%)	 {'predicted': '.', 'actual': 'valley', 'mask_idx': 83}
# 9936/10000 (99%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 12}
# 9937/10000 (99%)	 {'predicted': '-', 'actual': 'movies', 'mask_idx': 12}
# 9938/10000 (99%)	 {'predicted': 'art', 'actual': 'arts', 'mask_idx': 76}
# 9939/10000 (99%)	 {'predicted': 'in', 'actual': 'within', 'mask_idx': 11}
# 9940/10000 (99%)	 {'predicted': 'there', 'actual': 'there', 'mask_idx': 67}
# 9941/10000 (99%)	 {'predicted': 'named', 'actual': 'patterned', 'mask_idx': 110}
# 9942/10000 (99%)	 {'predicted': 'built', 'actual': 'used', 'mask_idx': 141}
# 9943/10000 (99%)	 {'predicted': '.', 'actual': 'in', 'mask_idx': 31}
# 9944/10000 (99%)	 {'predicted': 'lebanon', 'actual': 'portugal', 'mask_idx': 62}
# 9945/10000 (99%)	 {'predicted': 'earned', 'actual': 'earned', 'mask_idx': 64}
# 9946/10000 (99%)	 {'predicted': 'they', 'actual': 'they', 'mask_idx': 32}
# 9947/10000 (99%)	 {'predicted': 'that', 'actual': 'work', 'mask_idx': 31}
# 9948/10000 (99%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 83}
# 9949/10000 (99%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 8}
# 9950/10000 (99%)	 {'predicted': 'more', 'actual': 'little', 'mask_idx': 64}
# 9951/10000 (99%)	 {'predicted': 'role', 'actual': 'conduct', 'mask_idx': 49}
# 9952/10000 (99%)	 {'predicted': 'warfare', 'actual': 'europe', 'mask_idx': 159}
# 9953/10000 (99%)	 {'predicted': 'monument', 'actual': 'head', 'mask_idx': 77}
# 9954/10000 (99%)	 {'predicted': 'large', 'actual': 'large', 'mask_idx': 75}
# 9955/10000 (99%)	 {'predicted': 'poker', 'actual': 'pool', 'mask_idx': 32}
# 9956/10000 (99%)	 {'predicted': 'in', 'actual': 'in', 'mask_idx': 28}
# 9957/10000 (99%)	 {'predicted': '##ware', 'actual': '<', 'mask_idx': 106}
# 9958/10000 (99%)	 {'predicted': 'of', 'actual': 'of', 'mask_idx': 89}
# 9959/10000 (99%)	 {'predicted': 'kosovo', 'actual': '<', 'mask_idx': 121}
# 9960/10000 (99%)	 {'predicted': 'advertisement', 'actual': 'introduction', 'mask_idx': 53}
# 9961/10000 (99%)	 {'predicted': 'london', 'actual': 'belfast', 'mask_idx': 46}
# 9962/10000 (99%)	 {'predicted': '.', 'actual': ';', 'mask_idx': 234}
# 9963/10000 (99%)	 {'predicted': 'of', 'actual': 'of', 'mask_idx': 100}
# 9964/10000 (99%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 28}
# 9965/10000 (99%)	 {'predicted': 'represented', 'actual': 'represented', 'mask_idx': 28}
# 9966/10000 (99%)	 {'predicted': 'in', 'actual': 'over', 'mask_idx': 186}
# 9967/10000 (99%)	 {'predicted': 'spot', 'actual': 'spot', 'mask_idx': 84}
# 9968/10000 (99%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 194}
# 9969/10000 (99%)	 {'predicted': 'his', 'actual': 'the', 'mask_idx': 102}
# 9970/10000 (99%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 144}
# 9971/10000 (99%)	 {'predicted': 'public', 'actual': 'sanctioned', 'mask_idx': 78}
# 9972/10000 (99%)	 {'predicted': 'to', 'actual': 'to', 'mask_idx': 12}
# 9973/10000 (99%)	 {'predicted': '(', 'actual': '(', 'mask_idx': 7}
# 9974/10000 (99%)	 {'predicted': 'that', 'actual': 'that', 'mask_idx': 42}
# 9975/10000 (99%)	 {'predicted': 'the', 'actual': 'the', 'mask_idx': 59}
# 9976/10000 (99%)	 {'predicted': 'also', 'actual': 'also', 'mask_idx': 36}
# 9977/10000 (99%)	 {'predicted': 'wife', 'actual': 'wife', 'mask_idx': 6}
# 9978/10000 (99%)	 {'predicted': ',', 'actual': ',', 'mask_idx': 147}
# 9979/10000 (99%)	 {'predicted': 'oil', 'actual': 'oil', 'mask_idx': 94}
# 9980/10000 (99%)	 {'predicted': 'emperor', 'actual': '<', 'mask_idx': 104}
# 9981/10000 (99%)	 {'predicted': '.', 'actual': '.', 'mask_idx': 17}
# 9982/10000 (99%)	 {'predicted': '.', 'actual': 'view', 'mask_idx': 0}
# 9983/10000 (99%)	 {'predicted': 'of', 'actual': 'of', 'mask_idx': 3}
# 9984/10000 (99%)	 {'predicted': 'is', 'actual': 'is', 'mask_idx': 87}
# 9985/10000 (99%)	 {'predicted': 'guard', 'actual': 'army', 'mask_idx': 29}
# 9986/10000 (99%)	 {'predicted': 'population', 'actual': 'population', 'mask_idx': 8}
# 9987/10000 (99%)	 {'predicted': 'the', 'actual': '<', 'mask_idx': 91}
# 9988/10000 (99%)	 {'predicted': 'close', 'actual': 'close', 'mask_idx': 13}
# 9989/10000 (99%)	 {'predicted': 'in', 'actual': 'for', 'mask_idx': 14}
# 9990/10000 (99%)	 {'predicted': 'keep', 'actual': 'keep', 'mask_idx': 161}
# 9991/10000 (99%)	 {'predicted': 'and', 'actual': 'and', 'mask_idx': 25}
# 9992/10000 (99%)	 {'predicted': 'his', 'actual': 'various', 'mask_idx': 90}
# 9993/10000 (99%)	 {'predicted': 'few', 'actual': 'few', 'mask_idx': 74}
# 9994/10000 (99%)	 {'predicted': 'on', 'actual': 'along', 'mask_idx': 101}
# 9995/10000 (99%)	 {'predicted': 'on', 'actual': 'on', 'mask_idx': 119}
# 9996/10000 (99%)	 {'predicted': 'time', 'actual': 'event', 'mask_idx': 67}
# 9997/10000 (99%)	 {'predicted': 'by', 'actual': 'by', 'mask_idx': 86}
# 9998/10000 (99%)	 {'predicted': 'second', 'actual': 'youngest', 'mask_idx': 78}
# 9999/10000 (99%)	 {'predicted': 'of', 'actual': 'of', 'mask_idx': 124}
# 10000/10000 (100%)	 {'predicted': 'immediately', 'actual': 'immediately', 'mask_idx': 83}

# %%
sum(1 if p['predicted'] == p['actual'] else 0 for p in performance)
# Out:
# 4996

# %%
len(performance)
# Out:
# 10000

# %%
lengths = [len(tokenizer(x[0])['input_ids']) for x in sequences]

# %%
combined = [{**p, 'length': l} for p, l in zip(performance, lengths)]

# %%
import json
with open('export_10k_bert_masked.json', 'w') as f:
    json.dump(combined, f)

# %%
sum(1 if x > 100 else 0 for x in wiki_lengths)
# Out:
# 0

# %%
wiki_lengths = [len(tokenizer(x)['input_ids']) for x in cleaned]

# %%
wiki_lengths

# %%
for x in range(1, 11):
    x *= 50
    num = len([w for w in wiki_lengths if w >= x])
    print(f'{num} articles with length >= {x}')
# Out:
# 1714 articles with length >= 50
# 1339 articles with length >= 100
# 870 articles with length >= 150
# 514 articles with length >= 200
# 264 articles with length >= 250
# 137 articles with length >= 300
# 70 articles with length >= 350
# 30 articles with length >= 400
# 16 articles with length >= 450
# 3 articles with length >= 500

# %%
[1,2,1,2,3].index(2)
# Out:
# 1

# %%
def get_random_window(data, num=10000, seq_len = 100):
    MASK_ID = 103
    
    response = []
    
    tokenized = [tokenizer(x)['input_ids'] for x in data]
    tokenized = [x for x in tokenized if len(x) >= seq_len]
    
    while len(response) < num:
        # pick a random line
        line = tokenized[randint(len(tokenized))]
        
        # get random start position
        start = randint(len(line) - seq_len)
        end = start + seq_len
        
        # mask a random token in window
        window = line[start:end]
        window[randint(seq_len)] = MASK_ID
        
        response.append((line, window))
        
    return response

# %%
get_random_window(cleaned)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (528 > 512). Running this sequence through the model will result in indexing errors
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-d78a5ebae473> in <module>
# ----> 1 get_random_window(cleaned)
#
# <ipython-input-13-ee17023a7188> in get_random_window(data, num, seq_len)
#      12
#      13         # get random start position
# ---> 14         start = randint(len(line) - seq_len)
#      15         end = start + seq_len
#      16
#
# mtrand.pyx in numpy.random.mtrand.RandomState.randint()
#
# _bounded_integers.pyx in numpy.random._bounded_integers._rand_int64()
#
# ValueError: low >= high

# %%
randint(10)
# Out:
# 7
